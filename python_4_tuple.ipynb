# %% [markdown]
# <a href="https://colab.research.google.com/github/poresiddhi-code/python-4-tuple.ipynb/blob/main/python_4_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tuple

# %% [markdown]
# What is Tuple
# Tuple is one of the four built-in collection data type. Tuple is a collection which is ordered and unchangeable (i.e. immutable)
#
# Duplicates are allowed
#
# Written in round bracket ()

# %% [markdown]
# Basic Implementation

# %%
# Let's define one tuple by putting some data in round brackets. Separate data must be separated by comma.

courses = ('ba', 'bcom', 'bsc')
print(courses)
print(type(courses))     # Note that we get class 'tuple' as output

# %% [markdown]
# Example

# %%
courses = ('ai', 'cyber security', 'bsc in data science')
print(courses)
print(type(courses))

# %%
# To access data, just like list, simply pass index within []

print(courses[1])    # Index 1 = Position 2

# %% [markdown]
# Example

# %%
# To access data, just like list, simply pass index within []
courses = ('ai', 'cyber security', 'bsc in data science')
print(courses)
print(courses[1])    # Index 1 = Position 2

# %%
# If you type courses. you'll get only two suggestions, meaning tuples has only two functions defined specifically for them. Let's explore them
# Check the last two entries when you run help()

help(tuple)

# %% [markdown]
# Example

# %%
# To access data, just like list, simply pass index within []
courses = ('ai', 'cyber security', 'bsc in data science')
print(courses)
print(courses[2])    # Index 1 = Position 2

# %%
# count() - returns number of occurances of value
# Here 'ba' is used only once, hence output is 1

print(courses.count('ba'))
print(courses.count('baa'))    # 'baa' not part of courses. Output = 0

# %% [markdown]
# Example

# %%
# count() - returns number of occurances of value
# Here 'cyber security' is used only once, hence output is 1

print(courses.count('cyber security'))
print(courses.count('ai'))

# %%
#  index() - returns the first index of value
# bsc in data scie...  is defined at third position (second index)
courses = ('ai', 'cyber security', 'bsc in data science')
print(courses.index('bsc in data science'))

# %% [markdown]
# Example

# %%
#  index() - returns the first index of value
# bsc is defined at third position (second index)
courses = ('ba', 'bcom', 'bsc')
print(courses.index('bsc'))

# %% [markdown]
# As you saw in list, you cannot add or change element of tuple once it is created. That's why there is no method like add() or insert() to tuple which allows you to add.
#
# Let's explore further

# %%
# Let's re-define courses, and allow duplicate

courses = ('ba', 'bcom', 'bsc', 'bsc', 'ba')
print(courses)
print(courses.count('bsc'))            # 'bsc' is used twice hence 2
print(courses.index('bsc'))            # index returns the index of first occurance (so even if bsc is defined at index 2 and index 3, output will be 2)

# %% [markdown]
# Example

# %%
# Let's re-define courses, and allow duplicate

courses = ('ai', 'bcom', 'bsc in data science', 'bsc in data science', 'ai')
print(courses)
print(courses.count('bsc in data science'))            # 'bsc in data science' is used twice hence 2
print(courses.index('ai'))            # index returns the index of first occurance (so even if bsc is defined at index 2 and index 3, output will be 2)

# %%
# As we saw in the list, whenever there is collection of data, for loop becomes important.
# Let's see simple example of for loop

for item in courses:
  print(item)

# %% [markdown]
# EXAMPLE

# %%
# As we saw in the list, whenever there is collection of data, for loop becomes important.
# Let's see simple example of for loop
courses = ('ai', 'bcom', 'bsc in data science', 'bsc in data science', 'ai')
print(courses)
for item in courses:
  print(item)

# %%
# Use enumerate() function to get index of element as well
courses = ('ba', 'bcom', 'bsc', 'bsc', 'ba')
for id, item in enumerate(courses):    # enumerate() returns index along with main data. Hence you need two variables at the left (id, item). These names could be any.
  print(id, item)

# %% [markdown]
# example

# %%
# Use enumerate() function to get index of element as well
courses = ('ai', 'bcom', 'bsc in data science', 'bsc in data science', 'ai')
for id, item in enumerate(courses):    # enumerate() returns index along with main data. Hence you need two variables at the left (id, item). These names could be any.
  print(id, item)

# %%
# Check length of the tuple
# len() comes handy. This function can be used over str, list, tuple and few more..
courses = ('ba', 'bcom', 'bsc', 'bsc', 'ba')
print(len(courses))

# %% [markdown]
# Example

# %%
# Check length of the tuple
# len() comes handy. This function can be used over str, list, tuple and few more..
courses = ('ai', 'bcom', 'bsc in data science', 'bsc in data science', 'ai')
print(len(courses))

# %%
# If you are storing numbers in tuple, you don't need ''

nums = (2, 3, 4)
print(type(nums))

# %% [markdown]
# example

# %%
# If you are storing numbers in tuple, you don't need ''

nums = (2, 3, 4)
print(type(nums))

# %%
nums = ('sid', 'om', 'kranti')
print(type(nums))

# %% [markdown]
# Example

# %%
# Mix of str and int and bool is allowed in tuple

data = ('ba', 2, True, 'bsc')
print(data)
print(type(data))

# %%
# Mix of str and int and bool is allowed in tuple

data = ('ba', 2, True, 'bsc','ai',5,6)
print(data)
print(type(data))

# %%
# For the sake of it, let's check data type of each of the object
data = ('ba', 2, True, 'bsc')
print(data)
print(type(data[0]))
print(type(data[1]))
print(type(data[2]))

# %%
# For the sake of it, let's check data type of each of the object
data = ('ba', 2, True, 'bsc','ai',5,6)
print(type(data[0]))
print(type(data[1]))
print(type(data[2]))

# %%
# Let's do the same with for loop
for item in data:
  print(item, type(item))

# %% [markdown]
# Example

# %%
# Let's do the same with for loop
data = ('ba', 2, True, 'bsc','ai',5,6)
for item in data:
  print(item, type(item))

# %% [markdown]
# Example

# %%
# TRICKY ONE. For single valued tuple, you have to add a comma, else it'll be treated as a string

new = ('50')              # this will be treated as string
print(type(new))

print('-----------------------------')

new1 = ('50',)            # this will be treated as tuple
print(type(new1))

# %% [markdown]
# Concat two tuples

# %%
# simply use + to combine two tuples into one

print(('a','b','c') + (1, 2, 3))

# %% [markdown]
# Example

# %%
# simply use + to combine two tuples into one

print(('a','b','c') + (1, 2, 3)+(1,2,3,4))

# %%
# More than two tuples can also be added the same way

new = ('50',)
new1 = ('apple',)
new2 = ('mango','orange')
print(new + new1 + new2)

# %% [markdown]
# Example

# %%
# More than two tuples can also be added the same way

new = ('50',)
new1 = ('apple',)
new2 = ('mango','orange','custer apple')
print(new + new1 + new2)

# %%
# To delete, use del
new = ('50',)
new1 = ('apple',)
new2 = ('mango','orange','custer apple')
del new2
# print(new2)    # This will give error because new2 is not defined any more, it's deleted already

# %% [markdown]
# Example

# %%
# To delete, use del
new2 = ('mango','orange','custer apple')
del new2
# print(new2)    # This will give error because new2 is not defined any more, it's deleted already

# %%
# check whether an element is in the tuple

fruits = ('apple','mango')

print('mango' in fruits)     # return True if 'mango' is part of fruits else False. Thanks to 'IN', it comes handy many times in the real world programs.
print('mangoes' in fruits)

# %% [markdown]
# example

# %%
fruits = ('apple','mango','custer apple')

print('mango' in fruits)     # return True if 'mango' is part of fruits else False. Thanks to 'IN', it comes handy many times in the real world programs.
print('mangoes' in fruits)

# %%
#  Algebraic operations like max, min etc

print(max(2, 1, 3, 7))
print(min(2, 1, 3, 7))

# %% [markdown]
# Example

# %%
#  Algebraic operations like max, min etc

print(max(2, 1, 3, 7,5))
print(min(2, 1, 3, 7,8))

# %%
# To convert list into a tuple
num = [1, 2, 3, 4]
new = tuple(num)

print(num)
print(new)

# %% [markdown]
# example

# %%
# To convert list into a tuple
num = [1, 2, 3, 4 , 6, 5 ,9]
new = tuple(num)

print(num)
print(new)

# %% [markdown]
# Playing with indexes

# %%
# Just like list, you can use -1 to get the last element, and -2 to get second last element

num = (1, 2, 3, 4,  6, 5, 7)
print(num[-1])
print(num[-2])

# %% [markdown]
# Example

# %%
# Just like list, you can use -1 to get the last element, and -2 to get second last element

num = (1, 2, 3, 4, 5, 6, 7)
print(num[-1])
print(num[-2])

# %%
# num has 7 elements i.e. indexes from 0 to 6. So 7th index will give error

print(num[6])   # = 7
# print(num[7])   # should give error

# %%
# num has 7 elements i.e. indexes from 0 to 6. So 7th index will give error
num = [1, 2, 3, 4 , 6, 5 ,9]
print(num[6])   # = 7
# print(num[7])   # should give error

# %%
courses = ('ba', 'bcom', 'bsc', 'be', 'ma', 'mcom',' msc', 'me')
print(courses[3:5])   # print courses from 3rd index to 5th
print(courses[3:])   # print courses from 3rd index onwards
print(courses[:3])   # print courses upto 3d index

# %% [markdown]
# Example

# %%
courses = ('ba', 'bcom', 'bsc', 'be', 'ma', 'mcom',' msc', 'me','bsc in data science','ai')
print(courses[3:5])   # print courses from 3rd index to 5th
print(courses[3:])   # print courses from 3rd index onwards
print(courses[:3])   # print courses upto 3d index

# %%
courses = ('ba', 'bcom', 'bsc', 'be', 'ma', 'mcom',' msc', 'me','bsc in data science','ai')
print(courses[-3:])   # print last three courses

# %% [markdown]
# Example

# %%
print(courses[-3:])   # print last three courses
